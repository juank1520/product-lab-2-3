# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (OneHotEncoder, MinMaxScaler)
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_squared_error, r2_score

from feature_engine.encoding import (OrdinalEncoder)
from sklearn.svm import SVC, LinearSVC

# %% [markdown]
# # 1) Cargamos los datasets train y test

# %%
data = pd.read_csv('train.csv')
dataX = data.drop('Survived', axis=1)
dataY = data['Survived']
dataX
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
dataTest = pd.read_csv('test.csv')
dataTest
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Botamos las variables que no nos sirven
dataX = dataX.drop('Name', axis=1)
dataX = dataX.drop('Ticket', axis=1)

dataTest = dataTest.drop('Name', axis=1)
dataTest = dataTest.drop('Ticket', axis=1)

# %% [markdown]
# # 2) Analizamos el target

# %%
total = dataY.count()
salvados = dataY.sum()
print('Porcentaje de salvados', salvados/total )
# Out:
# Porcentaje de salvados 0.3838383838383838

# %% [markdown]
# Podemos decir que los datos están balanceados

# %% [markdown]
# # 3) Analizamos los datos faltantes

# %%
varsNas = [var for var in dataX.columns if(dataX[var].isnull().sum() > 0 )]
dataX[varsNas].isnull().mean().sort_values(ascending = False).plot.bar()
plt.ylabel('Porcentajes de NAs')
plt.axhline(y = 0.9, color = 'r')
plt.axhline(y = 0.75, color = 'g')

# %% [raw]
# Existen muchos faltantes en cabin, no conviene tomarla en cuenta para el análisis

# %% [markdown]
# ## 3.1) Eliminamos las variables que tienen demasiados faltantes

# %%
dataX = dataX.drop('Cabin', axis=1)
dataTest = dataTest.drop('Cabin', axis=1)

# %% [markdown]
# ## 3.2) Analizamos imputación por media y mediana para los numéricos faltantes

# %%
meanAge = dataX['Age'].mean()
medianAge = dataX['Age'].median()

meanFare = dataX['Fare'].mean()

dataImputation = pd.DataFrame()
dataImputation['Age'] = dataX.Age
dataImputation['mean'] = dataX.Age
dataImputation['median'] = dataX.Age

dataImputation['mean'].fillna( meanAge, inplace=True )
dataImputation['median'].fillna( medianAge, inplace=True )

# %%
dataImputation['Age'].hist()
plt.show()

dataImputation['mean'].hist()
plt.show()

dataImputation['median'].hist()
plt.show()

# %% [markdown]
# La imputación por media y por mediana nos da casi los mismos resultados, así que utilizaremos imputación por media

# %%
dataX['Age'].fillna( meanAge, inplace=True )
dataX['Fare'].fillna( meanFare, inplace=True )

dataTest['Age'].fillna( meanAge, inplace=True )
dataTest['Fare'].fillna( meanFare, inplace=True )

# %% [markdown]
# ## 3.3) Reemplazamos los missings en las variables categoricas

# %%
dataX['Embarked'] = dataX['Embarked'].fillna('Missing')

# %% [markdown]
# # 4) Variables categóricas

# %% [markdown]
# ## 4.1) Separamos las variables categóricas

# %%
categoricalVars = ['Pclass', 'Sex', 'Embarked']
categoricalVars
# Out:
# ['Pclass', 'Sex', 'Embarked']

# %% [markdown]
# ## 4.2) Tratamos las categóricas binarias

# %%
categoricalBinary  = ['Sex']

# Hacemos one hot encoadin de las variables categoricas binarias
binaryEncoder = OrdinalEncoder(encoding_method='ordered', variables=categoricalBinary)
binaryEncoder.fit(dataX, dataY)

dataX = binaryEncoder.transform(dataX)
dataTest = binaryEncoder.transform(dataTest)

# %% [markdown]
# ## 4.2) Separamos y analizamos las categóricas oridinales

# %%
categoricalOrdinal = ['Pclass']

# %%
# Verificamos que no hayan etiquetas
for var in categoricalOrdinal:
    print(dataX[var].unique())
# Out:
# [3 1 2]

# %% [markdown]
# ## 4.3) Separamos y analizamos las categóricas nominales

# %%
categoricalNominal = ['Embarked']

for var in categoricalNominal:
    temp = dataX.groupby(var)['Embarked'].count()/len(data)
    print(temp)
    print()
# Out:
# Embarked
# C          0.188552
# Missing    0.002245
# Q          0.086420
# S          0.722783
# Name: Embarked, dtype: float64

# %%
# Codificamos las variables nominales
ordinalEncoder = OrdinalEncoder(encoding_method='ordered', variables=categoricalNominal)
ordinalEncoder.fit(dataX, dataY)

dataX = ordinalEncoder.transform(dataX)
dataTest = ordinalEncoder.transform(dataTest)

# %% [markdown]
# # 5) Analizamos las variables numericas

# %%
numericalVariables = ['Age', 'SibSp', 'Parch', 'Fare']
dataX[numericalVariables].hist(figsize=(15, 15))
plt.show()

# %%
temp_yj = dataX.copy()
temp_log = dataX.copy()

temp_yj['Survived'] = dataY
temp_log['Survived'] = dataY

for var in numericalVariables:
    temp_yj[var], param = stats.yeojohnson(dataX[var])
    temp_log[var] = np.log(dataX[var])

    
temp_yj[numericalVariables].hist(figsize=(15, 15))
plt.show()
# Out:
# C:\Users\juan_\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# Age y Fare tienen una buena transformacion con yeo johnson

# %%
dataX['Age'], paramAge = stats.yeojohnson(dataX['Age'])
dataX['Fare'], paramFare = stats.yeojohnson(dataX['Fare'])

dataTest['Age'] = stats.yeojohnson(dataTest['Age'], lmbda=paramAge)
dataTest['Fare'] = stats.yeojohnson(dataTest['Fare'], lmbda=paramFare)

# %% [markdown]
# # 6) Feature Scaling

# %%
scaler = MinMaxScaler()
scaler.fit(dataX)

dataX = pd.DataFrame(scaler.transform(dataX), columns=dataX.columns)
dataTest = pd.DataFrame(scaler.transform(dataTest), columns=dataTest.columns)

# %% [markdown]
# # 7) Creación del modelo con SVC

# %%
linear_svc = LinearSVC()
linear_svc.fit(dataX, dataY)


Y_pred = linear_svc.predict(dataTest)
acc_linear_svc = round(linear_svc.score(dataX, dataY) * 100, 2)

# %%
acc_linear_svc
# Out:
# 80.13
